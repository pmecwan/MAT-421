# %% [markdown]
# <a href="https://colab.research.google.com/github/pmecwan/MAT-421/blob/main/Module_E_Section_3_2%2C_3_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.2 Continuity and differentiation

# %% [markdown]
# A limit defines the value a function approaches as the input approaches a point, the derivative measures the sensitivity of a function's output to changes in its input, and continuity ensures a function has no abrupt changes. The Mean Value Theorem and Taylor’s Theorem provide insights into function behavior and enable polynomial approximations of differentiable functions.

# %% [markdown]
# The derivative of a function of a real variable quantifies how sensitive the function's output is to changes in its input. It measures the rate at which the function's value changes with respect to changes in another variable. The derivative represents the instantaneous rate of change of the function at a specific point.

# %%
import numpy as np

x=Symbol('x')
y=x**(4)
yprime=y.diff(x)
yprime
# Out:
# 4*x**3

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-4,4,50)
y1=2*x
y2=1/x

plt.figure
plt.plot(x,y1,'-r')
plt.plot(x,y2,'-b')
plt.title('Continuity')
# Out:
# Text(0.5, 1.0, 'Continuity')

# %% [markdown]
# 3.2.3 Taylor theorem

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

h = 0.1
x = np.arange(0, 2*np.pi, h)
y = np.cos(x)

forward_diff = np.diff(y)/h
x_diff = x[:-1:]
exact_solution = -np.sin(x_diff)

plt.figure(figsize = (12, 8))
plt.plot(x_diff, forward_diff, '--', label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution,     label = 'Exact solution')
plt.legend()
plt.show()

max_error = max(abs(exact_solution - forward_diff))
print("Max Error: " + str(max_error))
# Out:
# Max Error: 0.049984407218554114

# %%
g=exp(x)
eq=sin(g)

taylorExpand = eq.series(x, 0, 3).removeO()
display(taylorExpand)



p1 = plot(eq, show=False)
p2 = plot(taylorExpand, show=False)
p1.append(p2[0])
print('Taylor expansion shows ok behavior near the 0')
p1.show()
# Out:
# x**2*(-sin(1)/2 + cos(1)/2) + x*cos(1) + sin(1)
# Taylor expansion shows ok behavior near the 0

# %% [markdown]
# 3.3.3 Optimization with gradient descent

# %% [markdown]
# A global minimizer is a point where the function attains its absolute lowest value across its entire domain.
#
# A local minimizer is a point where the function attains its lowest value within a small neighborhood, but this value may not necessarily be the absolute lowest value of the function globally.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def f(x):
    return x**4 - 4*x**2 + x

x_values = np.linspace(-2, 2, 500)
y_values = f(x_values)

plt.plot(x_values, y_values, label='f(x) = x^4 - 4x^2 + x')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of the function')
plt.grid(True)
plt.legend()

result_global = minimize(f, x0=0)
x_global_min = result_global.x
y_global_min = result_global.fun

plt.plot(x_global_min, y_global_min, 'ro', label=f'Global Minimizer: ({x_global_min[0]:.2f}, {y_global_min:.2f})')

result_local = minimize(f, x0=2)
x_local_min = result_local.x
y_local_min = result_local.fun

plt.plot(x_local_min, y_local_min, 'go', label=f'Local Minimizer: ({x_local_min[0]:.2f}, {y_local_min:.2f})')
plt.legend()
plt.show()
