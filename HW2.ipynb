# %% [markdown]
# <a href="https://colab.research.google.com/github/pmecwan/MAT-421/blob/main/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Interpolation Problem Statement

# %% [markdown]
# Interpolation is when we find a function baseed off of data points, results are calculated through all given data points.

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [2, 4, 3.5, 4.5]

plt.figure(figsize = (3,3))
plt.plot(x,y,'o')
plt.title('Data Set')
plt.ylim(0, 10)
plt.xlabel('xi')
plt.ylabel('yi')
plt.show()

# %% [markdown]
# Linear Interpolation

# %% [markdown]
# Linear interpolation is a simple method of estimation where the point to be estimated is assumed to lie on the straight line connecting the two nearest points, one on the left and one on the right.

# %%
plt.figure(figsize = (10, 8))
plt.plot(x, y, '-ob')
plt.plot(0.5, y_hat, 'ro')
plt.title('Linear Interpolation at x = 0.5')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Example: Find the linear interpolation at x = 0.5.
#  based on the data x = [0,1,2], y = [3,1,2]

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt


x = [0, 1, 2]
y = [3, 1, 2]

f = interp1d(x,y)
y_hat = f(0.5)
print(y_hat)
# Out:
# 2.0

# %% [markdown]
# Test for Linear Interpolation at decimal value where x > 1.

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [1, 3, 2, 7, 0, 1]

f = interp1d(x, y)
y_hat = f(4.2)
print(y_hat)

plt.figure(figsize = (7,7))
plt.plot(x, y, '-ob')
plt.plot(4.1, y_hat, 'ro')
plt.title('Linear Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 0.20000000000000018

# %% [markdown]
# Cubic Spline Interpolation

# %% [markdown]
# Cubic spline interpolation uses a series of piecewise cubic functions to create the interpolating curve. Each pair of adjacent points, 𝑥 𝑖 x i​and 𝑥 𝑖 + 1 x i+1​, is connected by a cubic polynomial 𝑆 𝑖 ( 𝑥 ) S i​(x), which is valid over the interval [ 𝑥 𝑖 , 𝑥 𝑖 + 1 ] [x i​,x i+1​] for 𝑖 = 1 , … , 𝑛 − 1 i=1,…,n−1.
#
# To construct the interpolating function, we need to determine the coefficients 𝑎 a, 𝑏 b, 𝑐 c, and 𝑑 d for each cubic polynomial. Since there are 𝑛 n points, this results in 𝑛 − 1 n−1 cubic functions, each with four coefficients, leading to a total of 4 ( 𝑛 − 1 ) 4(n−1) equations

# %%
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt

x = [0, 1, 2]
y = [3, 7, 5]
f = CubicSpline(x, y, bc_type='natural')
x_new = np.linspace(0, 2, 100)
y_new = f(x_new)

# plotting interpolation
plt.figure(figsize = (10,8))
plt.plot(x_new, y_new, 'b')
plt.plot(x, y, 'ro')
plt.title('Cubic Spline Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
